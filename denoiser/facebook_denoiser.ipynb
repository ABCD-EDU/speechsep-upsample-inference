# %%
# !python -m denoiser.enhance --noisy_dir=noisy/ --out_dir=cleaned/
# Out:
# Waiting for pending jobs...
# INFO:denoiser.pretrained:Loading pre-trained real time H=48 model trained on DNS.
#  16.7%
#  33.3%
#  50.0%
#  66.7%
#  83.3%
#  100.0%
# INFO:__main__:Generate enhanced files | 1/6 | 30.3 it/sec
# INFO:__main__:Generate enhanced files | 2/6 | 39.0 it/sec
# INFO:__main__:Generate enhanced files | 3/6 | 44.0 it/sec
# INFO:__main__:Generate enhanced files | 4/6 | 46.3 it/sec
# INFO:__main__:Generate enhanced files | 5/6 | 49.6 it/sec
# INFO:__main__:Generate enhanced files | 6/6 | 57.4 it/sec
# INFO:__main__:Generate enhanced files | 1/6 | 0.3 it/sec
# INFO:__main__:Generate enhanced files | 2/6 | 0.5 it/sec
# INFO:__main__:Generate enhanced files | 3/6 | 0.6 it/sec
# INFO:__main__:Generate enhanced files | 4/6 | 0.7 it/sec
# INFO:__main__:Generate enhanced files | 5/6 | 0.8 it/sec
# INFO:__main__:Generate enhanced files | 6/6 | 0.9 it/sec
