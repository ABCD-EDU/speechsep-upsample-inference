# %%
import os

dir_path = "results//audio_results_upsampled_partial"
# keyword = "hat_up"

item_set = set()
for filename in os.listdir(dir_path):
   item_num = filename.split("_")[0]
   if "hat_up" in filename:
      item_set.add(item_num)
      os.remove(os.path.join(dir_path, filename))
      continue
   if item_num in item_set:
      os.remove(os.path.join(dir_path, filename))
      # os.remove(os.path.join(dir_path, filename))

# %%
len(os.listdir(dir_path))
# Out:
# 13911

# %%
for filename in os.listdir(dir_path):
   if "item1000" in filename.split("_")[0]:
      os.remove(os.path.join(dir_path, filename))

# %%
item_set[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 item_set[0]
#
# TypeError: 'set' object is not subscriptable
